# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../input/train_folds.csv")

# %%
df.head()
# Out:
#          id  sentiment                                             review  \
# 0   10317_7          1  You know how Star Trek fans flocked to all the...
# 1   12041_9          1  This is a plain old spooky ghost story. I show...
# 2  10205_10          1  REnted this one accidentally, it was behind th...
# 3    6393_4          0  I will admit that I did not give this movie mu...
# 4    5625_8          1  Attractive Marjorie(Farrah Fawcett)lives in fe...
#
#    kfold
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
sns.countplot(x="kfold", data=df)
plt.show()
